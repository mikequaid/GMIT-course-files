# %%
# Pandas - for data frames.
import pandas as pd

# %%
# Read the data file.
df = pd.read_csv("http://cli.met.ie/cli/climate_data/webdata/hly4935.csv",skiprows=23,low_memory=False, nrows=1000)

# %%
# Look at the data.
df
# Out:
#                   date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1    31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2    31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3    31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4    31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# 5    31-jul-1996 12:00    0  0.0      0  14.4      0  10.9    7.3    0.0
# 6    31-jul-1996 13:00    0  0.0      0  14.9      0  10.9    6.7    0.0
# 7    31-jul-1996 14:00    0  0.0      0  13.9      0  10.4    6.7    0.0
# 8    31-jul-1996 15:00    0  0.0      0  13.2      0  10.9    8.6    0.0
# 9    31-jul-1996 16:00    0  0.0      0  15.1      0  11.3    7.5    0.0
# 10   31-jul-1996 17:00    0  0.0      0  11.6      0  10.6    9.6    0.0
# 11   31-jul-1996 18:00    0  0.0      0  13.3      0  10.9    8.5    0.0
# ...

# %%
pd.to_datetime(df['date'])
# Out:
# 0     1996-04-10 14:00:00
# 1     1996-07-31 08:00:00
# 2     1996-07-31 09:00:00
# 3     1996-07-31 10:00:00
# 4     1996-07-31 11:00:00
# 5     1996-07-31 12:00:00
# 6     1996-07-31 13:00:00
# 7     1996-07-31 14:00:00
# 8     1996-07-31 15:00:00
# 9     1996-07-31 16:00:00
# 10    1996-07-31 17:00:00
# 11    1996-07-31 18:00:00
# 12    1996-07-31 19:00:00
# 13    1996-07-31 20:00:00
# 14    1996-07-31 21:00:00
# 15    1996-07-31 22:00:00
# 16    1996-07-31 23:00:00
# 17    1996-08-01 00:00:00
# 18    1996-08-01 01:00:00
# 19    1996-08-01 02:00:00
# 20    1996-08-01 03:00:00
# 21    1996-08-01 04:00:00
# 22    1996-08-01 05:00:00
# 23    1996-08-01 06:00:00
# 24    1996-08-01 07:00:00
# 25    1996-08-01 08:00:00
# 26    1996-08-01 09:00:00
# 27    1996-08-01 10:00:00
# 28    1996-08-01 11:00:00
# 29    1996-08-01 12:00:00
#               ...
# 970   1996-09-09 17:00:00
# 971   1996-09-09 18:00:00
# 972   1996-09-09 19:00:00
# 973   1996-09-09 20:00:00
# 974   1996-09-09 21:00:00
# ...

# %%
import seaborn as sns
df1 = pd.read_csv("http://cli.met.ie/cli/climate_data/webdata/hly4935.csv",skiprows=23,low_memory=False, nrows=100)
sns.lineplot(x="datetime", y="temp", data=df1)
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-b20ac5e67e98> in <module>()
#       1 import seaborn as sns
#       2 df1 = pd.read_csv("http://cli.met.ie/cli/climate_data/webdata/hly4935.csv",skiprows=23,low_memory=False, nrows=100)
# ----> 3 sns.lineplot(x="datetime", y="temp", data=df1)
#       4 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
import pandas as pd
rng = pd.date_range('1/1/2011', periods=72, freq='H')
rng
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                '2011-01-01 10:00:00', '2011-01-01 11:00:00',
#                '2011-01-01 12:00:00', '2011-01-01 13:00:00',
#                '2011-01-01 14:00:00', '2011-01-01 15:00:00',
#                '2011-01-01 16:00:00', '2011-01-01 17:00:00',
#                '2011-01-01 18:00:00', '2011-01-01 19:00:00',
#                '2011-01-01 20:00:00', '2011-01-01 21:00:00',
#                '2011-01-01 22:00:00', '2011-01-01 23:00:00',
#                '2011-01-02 00:00:00', '2011-01-02 01:00:00',
#                '2011-01-02 02:00:00', '2011-01-02 03:00:00',
#                '2011-01-02 04:00:00', '2011-01-02 05:00:00',
# ...

# %%
import numpy as np
ts = pd.DataFrame(np.random.randn(len(rng)), index=rng)
ts
# Out:
#                             0
# 2011-01-01 00:00:00 -0.893473
# 2011-01-01 01:00:00  0.883989
# 2011-01-01 02:00:00  0.672124
# 2011-01-01 03:00:00 -0.069936
# 2011-01-01 04:00:00  0.203945
# 2011-01-01 05:00:00 -0.582096
# 2011-01-01 06:00:00 -0.889315
# 2011-01-01 07:00:00 -1.693444
# 2011-01-01 08:00:00  1.400204
# 2011-01-01 09:00:00 -0.309334
# 2011-01-01 10:00:00 -0.290790
# 2011-01-01 11:00:00 -0.279411
# 2011-01-01 12:00:00 -0.357549
# 2011-01-01 13:00:00 -1.201705
# 2011-01-01 14:00:00  0.847960
# 2011-01-01 15:00:00 -0.309917
# 2011-01-01 16:00:00 -0.190017
# 2011-01-01 17:00:00 -0.048624
# 2011-01-01 18:00:00 -0.916042
# 2011-01-01 19:00:00  1.461586
# 2011-01-01 20:00:00  1.478542
# 2011-01-01 21:00:00  0.363296
# 2011-01-01 22:00:00 -1.653922
# 2011-01-01 23:00:00 -1.421241
# 2011-01-02 00:00:00  0.067175
# 2011-01-02 01:00:00  0.143309
# 2011-01-02 02:00:00 -0.186058
# 2011-01-02 03:00:00  0.186186
# 2011-01-02 04:00:00 -1.102461
# 2011-01-02 05:00:00 -0.114650
# ...
